# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os

# %%
import AnalysisPanel
import utils
import matplotlib.pyplot as plt
import numpy as np

# %%
ap = AnalysisPanel.AnalysisPanel(
    dataPath='../Data/first',
    nBinsInterpolation=1000,
    parts=['duodenum'],
    windowSize = [0.4, 0.25]
)
# windowSize == [windowSizeHorizontal, windowSizeVertical]

# %%
ap.getAllCIH() #This may take some time, because the method is dealing with all the histograms.
# Out:
# start
# working on duodenum|
# end

# %%
ap.displayAllWidthAndDistance(yCutRatioForWidthToDisplay=[0.1,1.0])
# Out:
# Width
#
#
#
# yCutRatio 0.1
# duodenum
# mean 48.86   std 5.74   median 48.67   min 37.31   max 60.02
#
#
#
#
# yCutRatio 1.0
# duodenum
# mean 61.26   std 8.90   median 63.26   min 47.04   max 76.24
#
#
#
#
#
#
#
# Distance
#
#
#
# yCutRatio 1.0
# duodenum
# mean 231.92   std 72.72   median 207.64   min 124.10   max 429.06

# %%
ap.setDefaultYCutRatioForWidth(0.1) # We can tune the default yCutRatio for width here. This will have effect on the result of plotCIH. Tuning this after getAllCIH saves time.

# %%
ap.plotCIH(part='duodenum', tissueIndex=14, fontsize=15);
