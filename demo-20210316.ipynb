# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os

# %%
import AnalysisPanel
import utils
import matplotlib.pyplot as plt
import numpy as np

# %%
ap = AnalysisPanel.AnalysisPanel(dataPath='../Data/first',nBinsInterpolation=1000, parts=['DC', 'duodenum', 'ileum', 'jejunum', 'PC'])

# %%
ap.getAllCIH() #This may take some time, because the method is dealing with all the histograms.
# Out:
# start
# working on DC|working on duodenum|working on ileum|working on jejunum|working on PC|
# end

# %%
ap.displayAllWidthAndDistance()
# Out:
# Width
#
#
#
# yCutRatio 0.1
# DC
# mean 57.05   std 6.27   median 57.62   min 45.36   max 74.79
#
# duodenum
# mean 51.49   std 6.30   median 50.27   min 38.01   max 62.53
#
# ileum
# mean 61.23   std 8.75   median 60.08   min 42.91   max 77.24
#
# jejunum
# mean 55.17   std 6.15   median 55.17   min 42.91   max 69.89
#
# PC
# mean 70.39   std 7.13   median 72.34   min 55.17   max 84.60
#
#
#
#
# yCutRatio 1.0
# DC
# mean 65.77   std 8.94   median 64.98   min 45.36   max 82.15
#
# duodenum
# mean 65.27   std 10.88   median 66.21   min 47.82   max 91.95
#
# ileum
# mean 77.31   std 13.01   median 78.47   min 52.72   max 101.76
#
# jejunum
# mean 71.40   std 10.84   median 72.34   min 45.36   max 101.76
#
# PC
# mean 81.79   std 10.85   median 80.92   min 60.08   max 111.57
#
#
#
#
#
#
#
# Distance
#
#
#
# yCutRatio 1.0
# DC
# mean 191.95   std 48.80   median 184.52   min 108.51   max 301.00
#
# duodenum
# mean 227.72   std 67.11   median 206.59   min 121.99   max 372.11
#
# ileum
# ...

# %%
ap.plotCIH(part='duodenum', tissueIndex=14, fontsize=15);

# %%
ap.plotAllCIH(fontsize=15) #Plots will be saved to log/histDemo. This may take some time, because the method is dealing with all the plots.

# %%
print(ap.info['PC']['result'][0.1]['width']) # show all the widths. The number 0.1 refers to yCutRatio
# Out:
# [67.43314825029108, 55.17257584114725, 72.33737721394857, 72.33737721394857, 64.98103376846234, 74.78949169577743, 67.43314825029108, 57.62469032297611, 60.07680480480474, 72.33737721394857, 74.78949169577743, 69.88526273211994, 72.33737721394857, 82.14583514126377, 67.43314825029108, 84.5979496230924, 74.78949169577743, 72.33737721394857, 74.78949169577743, 64.98103376846234, 64.98103376846234, 72.33737721394857, 72.33737721394857, 77.24160617760617, 82.14583514126377, 60.07680480480474, 64.98103376846234, 84.5979496230924, 69.88526273211994, 69.88526273211994, 62.528919286633595, 72.33737721394857, 62.528919286633595, 74.78949169577743]

# %%
print(ap.info['PC']['result'][1.0]['distance'])
# Out:
# [231.11178991236133, 150.192012012012, 188.1997864803579, 194.3300726849298, 199.23430164858738, 206.59064509407364, 174.71315683029965, 133.02721063921064, 191.87795820310106, 166.130756143899, 256.8589919715634, 160.00046993932708, 271.571678862536, 258.08504921247777, 275.24985058527915, 272.7977361034504, 234.78996163510448, 218.8512175032175, 232.33784715327573, 175.93921407121405, 233.56390439419008, 228.65967543053256, 183.2955575167004, 238.46813335784765, 164.90469890298462, 220.0772747441319, 155.09624097566956, 264.2153354170497, 182.06950027578597, 174.71315683029965, 169.80892786664214, 174.71315683029965, 297.31888092173807, 185.74767199852914]
